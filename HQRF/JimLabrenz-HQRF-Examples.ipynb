# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import json
import seaborn
from os.path import join
# %matplotlib inline

# %%
from PRmm.extras import activityPlots
from PRmm.model import Fixture

fx = Fixture.fromIniFile(
    "/home/UNIXHOME/dalexander/Projects/Bugs/Dromedary-HQRF/fixtures.ini",
    "X1E3")

fxPoC = Fixture.fromIniFile(
    "/home/UNIXHOME/dalexander/Projects/Bugs/Dromedary-HQRF/fixtures.ini",
    "PoC")

# %%
hn = 11272631
activityPlots.plotMetrics(fx[hn])
activityPlots.plotMetrics(fxPoC[hn])
metrics = activityPlots.computeMetrics(fx[hn])

# %%
len(metrics)
activity = np.zeros(len(metrics))
activity.fill(1)
#metrics.HalfSandwichRate > 0.06
activity[(metrics.HalfSandwichRate >= 0.06)] = 2
# Out:
# /Users/dalexander/.virtualenvs/VE-Qt/lib/python2.7/site-packages/ipykernel/__main__.py:5: FutureWarning: in the future, boolean array-likes will be handled as a boolean array index

# %%
hn = 11272632
activityPlots.plotMetrics(fx[hn])
activityPlots.plotMetrics(fxPoC[hn])

# %%
fx.movieName
# Out:
# 'm54006_160119_012200'

# %%
hn = 11272634
activityPlots.plotMetrics(fx[hn])
activityPlots.plotMetrics(fxPoC[hn])
