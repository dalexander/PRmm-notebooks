# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import json
import seaborn
from os.path import join
# %matplotlib inline
# Out:
# /home/UNIXHOME/mlakata/git/PRmm/VE/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
from PRmm.extras import activityPlots
from PRmm.fixture import Fixture

fx = Fixture.fromIniFile(
    "/home/UNIXHOME/dalexander/Projects/Bugs/Dromedary-HQRF/LabrenzEcoli/fixtures.ini",
    "X1E3")

fxPoC = Fixture.fromIniFile(
    "/home/UNIXHOME/dalexander/Projects/Bugs/Dromedary-HQRF/LabrenzEcoli/fixtures.ini",
    "PoC")

# %%
hn = 11272631
activityPlots.plotMetrics(fx[hn])
activityPlots.plotMetrics(fxPoC[hn])
metrics = activityPlots.computeMetrics(fx[hn])
# Out:
# /home/UNIXHOME/mlakata/git/PRmm/VE/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
len(metrics)
activity = np.zeros(len(metrics))
activity.fill(1)
#metrics.HalfSandwichRate > 0.06
activity[(metrics.HalfSandwichRate >= 0.06)] = 2

# %%
hn = 11272632
activityPlots.plotMetrics(fx[hn])
activityPlots.plotMetrics(fxPoC[hn])

# %%
fx.movieName

# %%
hn = 11272634
activityPlots.plotMetrics(fx[hn])
activityPlots.plotMetrics(fxPoC[hn])

# %%
fx
# Out:
# <Fixture
#   alnF=<CmpH5Reader for /pbi/analysis/smrtportal/internal/userdata/jobs/258/258885/data/aligned_reads.cmp.h5>,
#   basF=<BasH5Reader: m54006_160119_012200>,
#   plsF=<PRmm.io.PlsH5IO.PlsH5Reader object at 0x7f085a67d590>,
#   refF=None,
#   trcF=<PRmm.io.TrcH5IO.TrcH5Reader object at 0x7f085a67d410> >
